# %% [markdown]
# # Знакомство с SymPy

# %% [markdown]
# ### Индивидуальное домашнее задание

# %% [markdown]
# ### Савин Глеб Сергеевич (sgs007), группа: М22-108

# %% [markdown]
# **Выполните указанные ниже действия, сохраните свою работу в виде ipynb-файла с именем `sgs007_hw00_22.ipynb` и прикрепите этот файл к сообщению своему преподавателю**.

# %% [markdown]
# **Задание 1.** Вычислите значение выражения $\displaystyle\ln\left(\frac{\sqrt2}{{(\log_27-1)}^2{(2+e)}^3}+\sqrt[5]{e^2}\right)$ с точностью 40 значащих десятичных цифр.

# %%
from sympy import *
N(log(sqrt(2)/((log(7, 2) - 1)**2*(2 + E)**3) + root(E**2, 5)), 40)
# Out:
# 0.4027590490436265268591873385981796817654

# %% [markdown]
# **Задание 2.** Раскройте скобки в выражении $\left(x - 2 y\right)^{3} \left(u + z - 1\right)^{3} \left(2 u + z - 1\right)^{3}$.

# %%
var('x y u z')
q = (x - 2*y)**3*(u + z - 1)**3*(2*u + z - 1)**3
expand(q)
# Out:
# 8*u**6*x**3 - 48*u**6*x**2*y + 96*u**6*x*y**2 - 64*u**6*y**3 + 36*u**5*x**3*z - 36*u**5*x**3 - 216*u**5*x**2*y*z + 216*u**5*x**2*y + 432*u**5*x*y**2*z - 432*u**5*x*y**2 - 288*u**5*y**3*z + 288*u**5*y**3 + 66*u**4*x**3*z**2 - 132*u**4*x**3*z + 66*u**4*x**3 - 396*u**4*x**2*y*z**2 + 792*u**4*x**2*y*z - 396*u**4*x**2*y + 792*u**4*x*y**2*z**2 - 1584*u**4*x*y**2*z + 792*u**4*x*y**2 - 528*u**4*y**3*z**2 + 1056*u**4*y**3*z - 528*u**4*y**3 + 63*u**3*x**3*z**3 - 189*u**3*x**3*z**2 + 189*u**3*x**3*z - 63*u**3*x**3 - 378*u**3*x**2*y*z**3 + 1134*u**3*x**2*y*z**2 - 1134*u**3*x**2*y*z + 378*u**3*x**2*y + 756*u**3*x*y**2*z**3 - 2268*u**3*x*y**2*z**2 + 2268*u**3*x*y**2*z - 756*u**3*x*y**2 - 504*u**3*y**3*z**3 + 1512*u**3*y**3*z**2 - 1512*u**3*y**3*z + 504*u**3*y**3 + 33*u**2*x**3*z**4 - 132*u**2*x**3*z**3 + 198*u**2*x**3*z**2 - 132*u**2*x**3*z + 33*u**2*x**3 - 198*u**2*x**2*y*z**4 + 792*u**2*x**2*y*z**3 - 1188*u**2*x**2*y*z**2 + 792*u**2*x**2*y*z - 198*u**2*x**2*y + 396*u**2*x*y**2*z**4 - 1584*u**2*x
# ...

# %% [markdown]
# **Задание 3.** Разложите на множители многочлен $4 u^{3} x^{4} + 20 u^{3} x^{3} y + 33 u^{3} x^{2} y^{2} + 20 u^{3} x y^{3} + 4 u^{3} y^{4} + 12 u^{2} x^{4} z + 60 u^{2} x^{3} y z + 99 u^{2} x^{2} y^{2} z + 60 u^{2} x y^{3} z + 12 u^{2} y^{4} z + 12 u x^{4} z^{2} + 60 u x^{3} y z^{2} + 99 u x^{2} y^{2} z^{2} + 60 u x y^{3} z^{2} + 12 u y^{4} z^{2} + 4 x^{4} z^{3} + 20 x^{3} y z^{3} + 33 x^{2} y^{2} z^{3} + 20 x y^{3} z^{3} + 4 y^{4} z^{3}$.

# %%
t = 4*u**3*x**4 + 20*u**3*x**3*y + 33*u**3*x**2*y**2 + 20*u**3*x*y**3 + 4*u**3*y**4 + 12*u**2*x**4*z + 60*u**2*x**3*y*z + 99*u**2*x**2*y**2*z + 60*u**2*x*y**3*z + 12*u**2*y**4*z + 12*u*x**4*z**2 + 60*u*x**3*y*z**2 + 99*u*x**2*y**2*z**2 + 60*u*x*y**3*z**2 + 12*u*y**4*z**2 + 4*x**4*z**3 + 20*x**3*y*z**3 + 33*x**2*y**2*z**3 + 20*x*y**3*z**3 + 4*y**4*z**3
factor(t)
# Out:
# (u + z)**3*(x + 2*y)**2*(2*x + y)**2

# %% [markdown]
# **Задание 4.** Найдите действительные корни уравнения $25 x^{4} + 50 x^{3} + 174 x^{2} - 2 x - 7 = 0$.

# %%
solveset(25*x**4 + 50*x**3 + 174*x**2 - 2*x - 7, x, domain = S.Reals)
# Out:
# FiniteSet(-1/5, 1/5)

# %% [markdown]
# **Задание 5.** Постройте график функции, заданной неявно: $\displaystyle - 3 x^{8} + 3 x^{4} - 2 y^{8} + 2 y^{4}=0$. Используйте одинаковый масштаб по координатным осям.

# %%
var('x y')
plot_implicit(-3*x**8 + 3*x**4 - 2*y**8 + 2*y**4, aspect_ratio = (1, 1))

# %% [markdown]
# **Задание 6.** Постройте график функции, заданной параметрически: $\displaystyle x(t)=3 \sin{\left(7 t \right)}$, $\displaystyle y(t)=3 \sin{\left(6 t \right)}$. Используйте минимальный по длине промежуток изменения параметра и одинаковый масштаб по координатным осям.

# %%
var('t')
plotting.plot_parametric(3*sin(7*t), 3*sin(6*t), (t, 0, 2*pi), aspect_ratio = (1, 1))
